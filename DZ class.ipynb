# %%
norma = 2500 
class Nutrition ():
    all = []
    money = int (input ('Please write down how much money you have = '))
    def __init__(self, name: str, price: int, estimation: int, calories: int):
        assert estimation <= 5, f'pleaase rate it on a 5-point scale'
        
        self.name = name
        self.price = price
        self.estimation = estimation
        self.calories = calories
        Nutrition.caloriy = 0
        
        self.quantity = 0
        self.number = 0
        
        if estimation >= 4:
            print('Thank you for the good rating')
        elif estimation < 4:
            print(f'Please tell me why you did not like the {self.name}')
            comment = str(input())
            print('Thanks for the comment, we will try to improve')
            
            
    def eat (self):
        if Nutrition.money > self.price:
            if (Nutrition.caloriy + self.calories) > norma:
                print(f'You probably should not eat anymore, you already ate {self.caloriy} calories the daily norm for men is 2800, and for women 2400')
            else:
                print(f'You are gained {self.calories} calories ')
                Nutrition.caloriy += self.calories
                Nutrition.money-= self.price
                
        else:
            print(f'You do not have enough money to buy {self.name}')
            
            
    def  food_calculate(self):
        self.quantity_half = 0
        self.quantity_quarter = 0
        half = self.calories / 2
        quarter = self.calories / 4
        
        while self.number < norma:
            if (self.number + self.calories) <= norma:
                self.number += self.calories
                self.quantity += 1
            elif (self.number + self.calories) > norma:
                if (self.number + half) <= norma:
                    self.number += half 
                    self.quantity_half = 0.5
                elif (self.number + half) > norma:
                    if (self.number + quarter) <= norma:
                        self.number += quarter
                        self.quantity_quarter = 0.25
                    elif (self.number + quarter) > norma:
                        big = self.number + quarter 
                        if (big - norma) < (norma - self.number):
                            self.number = big
                            self.quantity_quarter = 0.25
                            break 
                        else:
                            return self.number 
                            break
                            
        
        print(f'To gain a daily calorie allowance you need to eat {self.quantity} {self.name}')
        if self.quantity_half == 0.5:
            print(f'And half {self.name}')
        if self.quantity_quarter == 0.25:
            print (f'And quarter {self.name}')
    def money_calculate(self):
        money_copy = Nutrition.money
        while money_copy >= 0:
            money_copy -= self.price
            self.quantity += 1 
        if money_copy < 0:
            self.quantity -= 1
            print(f'You can buy {self.quantity} {self.name}')
# Out:
# Please write down how much money you have = 1500

# %%
norma_water = 2 
class Drink(Nutrition):
    
    def __init__(self, name: str, price: int, water: int):
        self.price = price 
        self.name = name 
        self.water = water 
        Nutrition.water_day = 0
        self.quantity = 0
        
        
    def drinking(self):
        if Nutrition.money > self.price:
            if (Nutrition.water_day + self.water) > norma_water:
                print(f'You probablyshould not drinking anymore, you already ate {self.water_day} the daily for people is 2 litre')
            else:
                Nutrition.water_day += self_water
                print(f'You have drink {Nutrition.water_day} liters of woter today ')
                Nutrition.money -= self.price
        else:
            print(f'You do not have enough money to buy {self.name}')
    
    
    def estimation (self):
        estimation1 = int(input('Put your rating on this drink : '))
        if estimation1 >= 4:
            print('Thank you for the good rating')
        elif estimation1 < 4:
            comment = str(input(f'Please tell me why you did not like the {self.name} : '))
            print('Thanks for the comment, we whill try to improve')

            
            

            
            
food1 = Nutrition('burger', 300, 4, 500)
# Out:
# Thank you for the good rating
